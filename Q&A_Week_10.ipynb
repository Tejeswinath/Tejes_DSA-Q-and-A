# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1.  Read the data into python

# %%
data=pd.read_csv(r"C:\Users\Tejes\Downloads\week10.csv")
data.head(10)
# Out:
#           ph    Hardness       Solids  Chloramines     Sulfate  Conductivity  \
# 0   8.316766  214.373394  22018.41744     8.059332  356.886136    363.266516
# 1   9.092223  181.101509  17978.98634     6.546600  310.135738    398.410813
# 2   5.584087  188.313324  28748.68774     7.544869  326.678363    280.467916
# 3  10.223862  248.071735  28749.71654     7.513408  393.663395    283.651634
# 4   8.635849  203.361523  13672.09176     4.563009  303.309771    474.607645
# 5  11.180284  227.231469  25484.50849     9.077200  404.041635    563.885481
# 6   7.360640  165.520797  32452.61441     7.550701  326.624353    425.383420
# 7   7.119824  156.704993  18730.81365     3.606036  282.344050    347.715027
# 8   6.347272  186.732881  41065.23476     9.629596  364.487687    516.743282
# 9   9.181560  273.813807  24041.32628     6.904990  398.350517    477.974642
#
#    Organic_carbon  Trihalomethanes  Turbidity
# 0       18.436525       100.341674   4.628771
# ...

# %% [markdown]
# # 2. Check for null values

# %%
data.isna().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# dtype: int64

# %%
data.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity'],
#       dtype='object')

# %%
selected_data=data[['Hardness','Sulfate','Organic_carbon']]

# %% [markdown]
# # 3. Examine the variables ‘Hardness’, ‘Sulfate’, and ‘Organic_carbon’ and comment on your observations.

# %%
selected_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2011 entries, 0 to 2010
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Hardness        2011 non-null   float64
#  1   Sulfate         2011 non-null   float64
#  2   Organic_carbon  2011 non-null   float64
# dtypes: float64(3)
# memory usage: 47.3 KB

# %%
selected_data.describe()
# Out:
#           Hardness      Sulfate  Organic_carbon
# count  2011.000000  2011.000000     2011.000000
# mean    195.968072   333.224672       14.357709
# std      32.635085    41.205172        3.324959
# min      73.492234   129.000000        2.200000
# 25%     176.744938   307.632511       12.124105
# 50%     197.191839   332.232177       14.322019
# 75%     216.441070   359.330555       16.683049
# max     317.338124   481.030642       27.006707

# %%
sns.pairplot(selected_data)

# %% [markdown]
# # 4. Carry out correlation analysis on the dataset and find the correlation factor between

# %%
correlation=data.corr()
plt.subplots(figsize=(8,4))
sns.heatmap(correlation,vmin=-1,vmax=1,annot=True,linewidth=0.2,cmap='bwr')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # a. ph & Chloromines Correlation

# %%
data[['ph','Chloramines']].corr()
# Out:
#                    ph  Chloramines
# ph           1.000000    -0.024768
# Chloramines -0.024768     1.000000

# %% [markdown]
# # b. ph & Conductivity Correlation

# %%
data[['ph','Conductivity']].corr()
# Out:
#                     ph  Conductivity
# ph            1.000000      0.014128
# Conductivity  0.014128      1.000000

# %%
# in cases a) & b) correlation value is close to zero, so we can say there is no linear correlation b/w a) ph & Chloromines  b) ph & Conductivity
